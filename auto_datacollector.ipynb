# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubh-bit44/Mini-projects-training/blob/Mini-project/auto_datacollector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Automated Data collector
import csv
import os

filename = "data.csv"

# Create file with header if it doesn't exist
if not os.path.exists(filename):
    with open(filename, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["ID", "Name", "Age", "City"])

# Function to add data
def add_data():
    id = input("Enter ID: ")
    name = input("Enter Name: ")
    age = input("Enter Age: ")
    city = input("Enter City: ")

    with open(filename, "a", newline="") as file:
        writer = csv.writer(file)
        writer.writerow([id, name, age, city])

    print("Record Saved Successfully!")

# Function to display data
def display_data():
    with open(filename, "r") as file:
        reader = csv.reader(file)
        print("\n--- All Records ---")
        for row in reader:
            print(row)

# Main Menu
while True:
    print("\n===== Automated Data Collector =====")
    print("1. Add Record")
    print("2. View Records")
    print("3. Exit")

    choice = input("Enter Choice: ")

    if choice == "1":
        add_data()

    elif choice == "2":
        display_data()

    elif choice == "3":
        print("Program Closed.")
        break

    else:
        print("Invalid Choice!")
# Out:
# ===== Automated Data Collector =====
# 1. Add Record
# 2. View Records
# 3. Exit
# Enter Choice: 1
# Enter ID: 1-1
# Enter Name: shubh
# Enter Age: 20
# Enter City: moradabad
# Record Saved Successfully!
#
# ===== Automated Data Collector =====
# 1. Add Record
# 2. View Records
# 3. Exit
# Enter Choice: 2
#
# --- All Records ---
# ['ID', 'Name', 'Age', 'City']
# ['1-1', 'shubh', '20', 'moradabad']
#
# ===== Automated Data Collector =====
# 1. Add Record
# 2. View Records
# 3. Exit
# Enter Choice: 1
# Enter ID: 765
# Enter Name: tarun
# Enter Age: 19
# Enter City: derabassi
# Record Saved Successfully!
#
# ===== Automated Data Collector =====
# 1. Add Record
# 2. View Records
# 3. Exit
# Enter Choice: 6
# Invalid Choice!
#
# ===== Automated Data Collector =====
# 1. Add Record
# 2. View Records
# 3. Exit
# Enter Choice: 3
# Program Closed.
